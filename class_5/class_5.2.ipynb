# %%
attendance = int(input("What's is attendance: "))
fee_paid = input("Is fee paid: ")
# Out:
# What's is attendance:  76
# Is fee paid:  no

# %%
if attendance > 75 and fee_paid == "yes":
   print("Eligible for exam")
else:
   print("Not eligible for exam")
# Out:
# Not eligible for exam

# %%
# Out:
# Not eligible for exam
