# %%
marks = int(input("Enter marks: "))
# Out:
# Enter marks:  90

# %%
if marks >= 90:
    print("A grade")
elif marks >= 80:
    print("B grade")
elif marks >= 70:
    print("C grade")
else:
     print("F grade")
# Out:
# A grade
