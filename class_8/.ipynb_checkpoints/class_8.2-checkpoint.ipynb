# %%
class Father:
    def skills(self):
        print("Driving skills")

class Mother:
    def skills(self):
        print("Cooking skills")

class Son(Father, Mother):
    def skills(self):
        print("Inherited skills from both parents")
        Father.skills(self)
        Mother.skills(self)

s = Son()

s.skills()
# Out:
# Inherited skills from both parents
# Driving skills
# Cooking skills
